# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyClientCredentials
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
client_id = os.getenv("CLIENT_ID")
client_secret = os.getenv("CLIENT_SECRET")

# Authentication - without user
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)
playlist_link = "https://open.spotify.com/playlist/5S8SJdl1BDc0ugpkEvFsIL?si=4b0bdca0cff04e13"
playlist_URI = playlist_link.split("/")[-1].split("?")[0]
track_uris = [x["track"]["uri"] for x in sp.playlist_tracks(playlist_URI)["items"]]

# %%
print(type(sp))
# Out:
# <class 'spotipy.client.Spotify'>

# %%
song_data = []
for track in sp.playlist_tracks(playlist_URI)["items"]:
    #URI
    track_uri = track["track"]["uri"]
    
    #Track name
    track_name = track["track"]["name"]
    #print(track_name)
    
    #Main Artist
    artist_uri = track["track"]["artists"][0]["uri"]
    artist_info = sp.artist(artist_uri)
    #print(artist_info['name'])
    
    #Name, popularity, genre
    artist_name = track["track"]["artists"][0]["name"]
    artist_pop = artist_info["popularity"]
    artist_genres = artist_info["genres"]
    
    #Album
    album = track["track"]["album"]["name"]
    #print(album)
    
    #Popularity of the track
    track_pop = track["track"]["popularity"]
    
    
    #creating df for album
    info = sp.audio_features(track_uri)[0]
    info['artist_name'] = artist_name
    info['artist_pop'] = artist_pop
    
    info['track_name'] = track_name
    info['track_popularity'] = track_pop
    info['album_name'] = album
    song_data.append(info)

# %%
df = pd.DataFrame(song_data)
df
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.615   0.779    2    -6.454     1       0.1350       0.06650
# 1          0.687   0.845    7    -4.370     1       0.0576       0.10000
# 2          0.818   0.803    1    -4.282     1       0.0797       0.03400
# 3          0.624   0.876    9    -3.374     1       0.1000       0.07350
# 4          0.614   0.379    4   -10.480     1       0.0476       0.60700
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.706   0.751    9    -6.323     1       0.0708       0.17300
# 96         0.754   0.804    4    -3.177     1       0.0853       0.00332
# 97         0.743   0.766    0    -6.375     1       0.0265       0.08730
# 98         0.672   0.738    0    -7.045     1       0.0506       0.01780
# 99         0.836   0.509    0   -13.668     1       0.0548       0.46700
#
#     instrumentalness  liveness  valence  ...  \
# 0           0.000000    0.1550    0.453  ...
# 1           0.000000    0.0452    0.809  ...
# 2           0.000000    0.1530    0.632  ...
# 3           0.000000    0.3270    0.781  ...
# 4           0.000464    0.0986    0.201  ...
# ..               ...       ...      ...  ...
# 95          0.000000    0.1680    0.195  ...
# 96          0.000000    0.0329    0.818  ...
# 97          0.000000    0.5090    0.610  ...
# 98          0.000068    0.0927    0.392  ...
# 99          0.000004    0.0436    0.949  ...
#
#                                      uri  \
# 0   spotify:track:7zgqtptZvhf8GEmdsM2vp2
# 1   spotify:track:4Vxu50qVrQcycjRyJQaZLC
# 2   spotify:track:6b8Be6ljOzmkOmFslEb23P
# 3   spotify:track:0afhq8XCExXpqazXczTSve
# 4   spotify:track:1HNkqx9Ahdgi1Ixy2xkKkL
# ..                                   ...
# 95  spotify:track:5vlEg2fT4cFWAqU5QptIpQ
# 96  spotify:track:1DqdF42leyFIzqNDv9CjId
# 97  spotify:track:4vp2J1l5RD4gMZwGFLfRAu
# 98  spotify:track:67WTwafOMgegV6ABnBQxcE
# 99  spotify:track:5IMtdHjJ1OtkxbGe4zfUxQ
#
#                                            track_href  \
# 0   https://api.spotify.com/v1/tracks/7zgqtptZvhf8...
# 1   https://api.spotify.com/v1/tracks/4Vxu50qVrQcy...
# 2   https://api.spotify.com/v1/tracks/6b8Be6ljOzmk...
# 3   https://api.spotify.com/v1/tracks/0afhq8XCExXp...
# 4   https://api.spotify.com/v1/tracks/1HNkqx9Ahdgi...
# ..                                                ...
# 95  https://api.spotify.com/v1/tracks/5vlEg2fT4cFW...
# 96  https://api.spotify.com/v1/tracks/1DqdF42leyFI...
# 97  https://api.spotify.com/v1/tracks/4vp2J1l5RD4g...
# 98  https://api.spotify.com/v1/tracks/67WTwafOMgeg...
# 99  https://api.spotify.com/v1/tracks/5IMtdHjJ1Otk...
#
#                                          analysis_url duration_ms  \
# 0   https://api.spotify.com/v1/audio-analysis/7zgq...      208198
# 1   https://api.spotify.com/v1/audio-analysis/4Vxu...      190227
# 2   https://api.spotify.com/v1/audio-analysis/6b8B...      225983
# 3   https://api.spotify.com/v1/audio-analysis/0afh...      170827
# 4   https://api.spotify.com/v1/audio-analysis/1HNk...      258987
# ..                                                ...         ...
# 95  https://api.spotify.com/v1/audio-analysis/5vlE...      182307
# 96  https://api.spotify.com/v1/audio-analysis/1Dqd...      203867
# 97  https://api.spotify.com/v1/audio-analysis/4vp2...      289133
# 98  https://api.spotify.com/v1/audio-analysis/67WT...      277040
# 99  https://api.spotify.com/v1/audio-analysis/5IMt...      276493
#
#    time_signature      artist_name  artist_pop                     track_name  \
# 0               4     Taylor Swift          92               ...Ready For It?
# 1               4     Thomas Rhett          74                   Life Changes
# 2               4       Bruno Mars          87                      24K Magic
# 3               4       Ed Sheeran          91                    Galway Girl
# 4               4       Ed Sheeran          91                     Photograph
# ..            ...              ...         ...                            ...
# 95              4             Iyaz          63                         Replay
# 96              4        Taio Cruz          69                       Dynamite
# 97              4  Black Eyed Peas          78                I Gotta Feeling
# 98              4             fun.          66                    Some Nights
# 99              4    Rupert Holmes          59  Escape (The Pina Colada Song)
#
#    track_popularity                          album_name
# 0                 0                    ...Ready For It?
# 1                63                        Life Changes
# 2                77                           24K Magic
# 3                77                          ÷ (Deluxe)
# 4                83                  x (Deluxe Edition)
# ..              ...                                 ...
# 95               72                              Replay
# 96               65                            Rokstarr
# 97               30  THE E.N.D. (THE ENERGY NEVER DIES)
# 98               69                         Some Nights
# 99               74                   Partners In Crime
#
# [100 rows x 23 columns]

# %%
df = df.drop(columns = ['type','id','uri','track_href','analysis_url'])
df.shape
# Out:
# (100, 18)

# %%
song_data[0]
# Out:
# {'danceability': 0.615,
#  'energy': 0.779,
#  'key': 2,
#  'loudness': -6.454,
#  'mode': 1,
#  'speechiness': 0.135,
#  'acousticness': 0.0665,
#  'instrumentalness': 0,
#  'liveness': 0.155,
#  'valence': 0.453,
#  'tempo': 160.0,
#  'type': 'audio_features',
#  'id': '7zgqtptZvhf8GEmdsM2vp2',
#  'uri': 'spotify:track:7zgqtptZvhf8GEmdsM2vp2',
#  'track_href': 'https://api.spotify.com/v1/tracks/7zgqtptZvhf8GEmdsM2vp2',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7zgqtptZvhf8GEmdsM2vp2',
#  'duration_ms': 208198,
#  'time_signature': 4,
#  'artist_name': 'Taylor Swift',
#  'artist_pop': 92,
#  'track_name': '...Ready For It?',
#  'track_popularity': 0,
#  'album_name': '...Ready For It?'}
